# %%
import numpy as np
import pandas as pd
df=pd.read_csv('1200 coded reports.csv')
df
# Out:
#       Unnamed: 0                     Upstream measurees  \
# 0              1                Machinery and Equipment
# 1              2                Machinery and Equipment
# 2              3         Exposure to harmful substance
# 3              4                      Working at height
# 4              5  Handling heavy/sharp object/materials
# 5              6        Exposure to extreme temperature
# 6              7         Exposure to harmful substance
# 7              8                Machinery and Equipment
# 8              9                      Working at height
# 9             10                      Working at height
# 10            11                      Working at height
# 11            12                      Working at height
# 12            13                         Heavy Vechicle
# 13            14                      Working at height
# 14            15         Exposure to harmful substance
# 15            16                         Heavy Vechicle
# ...

# %%
len(df[df[Upstream measurees]== 'Machinery and Equipment'])
# Out:
#   File "<ipython-input-20-464139012c2b>", line 1
#     len(df[df[Upstream measurees]== 'Machinery and Equipment'])
#                                ^
# SyntaxError: invalid syntax

# %%
df.drop('Unnamed: 0', axis=1, inplace= True )
df.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-21-f14ea07dc9e8> in <module>
# ----> 1 df.drop('Unnamed: 0', axis=1, inplace= True )
#       2 df.head()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3938                                            index=index, columns=columns,
#    3939                                            level=level, inplace=inplace,
# -> 3940                                            errors=errors)
#    3941
#    3942     @rewrite_axis_style_signature('mapper', [('copy', True),
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3778         for axis, labels in axes.items():
#    3779             if labels is not None:
# ...

# %%
df.tail()
# Out:
#              Upstream measurees  \
# 1195         Working at Height
# 1196         Working at Height
# 1197         Working at Height
# 1198         Working at Height
# 1199  Machinery and equipment
#
#                                                  REPORT ENERGY SOURCE  \
# 1195  At 2:45 p.m. on February 24, 2017, an employee...       Gravity
# 1196  At 2:30 p.m. on February 24, 2017, an employee...       Gravity
# 1197  At 1:15 p.m. on February 24, 2017, an employee...       Gravity
# 1198  At 1:45 p.m. on February 24, 2017, an employee...       Gravity
# 1199  At approximately 1:45 a.m. on February 24, 201...    Mechanical
#
#               ACCIDENT TYPE INJURY SEVERITY
# 1195  Fall (from elevation)    Hospitalized
# 1196  Fall (from elevation)    Hospitalized
# 1197  Fall (from elevation)    Hospitalized
# 1198  Fall (from elevation)    Hospitalized
# 1199                  Other    Minor injury

# %%
df.shape
# Out:
# (1200, 5)

# %%
df[['ENERGY SOURCE','REPORT']]
# Out:
#      ENERGY SOURCE                                             REPORT
# 0       Mechanical  At 9:00 a.m. on August 10, 2017, an employee w...
# 1       Mechanical  At 9:45 a.m. on July 17, 2017, an employee was...
# 2      Temperature  At 7:30 a.m. on June 30, 2017, an employee was...
# 3          Gravity  At 2:00 p.m. on June 30, 2017, an employee was...
# 4           Motion  At 12:20 p.m. on June 23, 2017, an employee wa...
# 5      Temperature  At 9:07 a.m. on June 22, 2017, an employee was...
# 6      Temperature  At 11:00 p.m. on May 31, 2017, nineteen employ...
# 7       Mechanical  At 11:00 a.m. on May 31, 2017, an employee was...
# 8          Gravity  At 5:15 p.m. on May 31, 2017, an employee was ...
# 9          Gravity  At 4:45 p.m. on May 31, 2017, an employee set ...
# 10         Gravity  At 4:29 p.m. on May 31, 2017, an employee was ...
# 11         Gravity  At 2:30 p.m. on May 31, 2017, an employee was ...
# ...

# %%
df.head()
# Out:
#                       Upstream measurees  \
# 0                Machinery and Equipment
# 1                Machinery and Equipment
# 2         Exposure to harmful substance
# 3                      Working at height
# 4  Handling heavy/sharp object/materials
#
#                                               REPORT ENERGY SOURCE  \
# 0  At 9:00 a.m. on August 10, 2017, an employee w...    Mechanical
# 1  At 9:45 a.m. on July 17, 2017, an employee was...    Mechanical
# 2  At 7:30 a.m. on June 30, 2017, an employee was...   Temperature
# 3  At 2:00 p.m. on June 30, 2017, an employee was...       Gravity
# 4  At 12:20 p.m. on June 23, 2017, an employee wa...        Motion
#
#            ACCIDENT TYPE INJURY SEVERITY
# 0      Caught in between    Minor injury
# 1      Caught in between    Minor injury
# 2     Fire and Explosion    Minor injury
# 3  Fall (from elevation)    Hospitalized
# 4              Struck-by    Hospitalized

# %%
df.sort_values('Upstream measurees').head()
# Out:
#         Upstream measurees                                             REPORT  \
# 1066  Entanged Work Space   At 9:45 a.m. on March 3, 2017, Employee #1, em...
# 1064  Entanged Work Space   At 10:15 p.m. on March 3, 2017, an employee wo...
# 1176  Entanged Work Space   At 1:00 p.m. on February 27, 2017, an employee...
# 1171  Entanged Work Space   At 2:30 p.m. on February 27, 2017, an employee...
# 1165  Entanged Work Space   At 4:45 p.m. on February 27, 2017, an employee...
#
#      ENERGY SOURCE          ACCIDENT TYPE INJURY SEVERITY
# 1066      Gravity       Fall (same level)    Hospitalized
# 1064   Mechanical   Fall (from elevation)    Hospitalized
# 1176       Motion               Struck-by    Hospitalized
# 1171       Motion               Struck-by    Hospitalized
# 1165   Mechanical               Struck-by    Hospitalized

# %%
df[df['Upstream measurees']=='Machinery and Equipment']
# Out:
#            Upstream measurees  \
# 0     Machinery and Equipment
# 1     Machinery and Equipment
# 7     Machinery and Equipment
# 18    Machinery and Equipment
# 20    Machinery and Equipment
# 21    Machinery and Equipment
# 109   Machinery and Equipment
# 111   Machinery and Equipment
# 121   Machinery and Equipment
# 135   Machinery and Equipment
# 136   Machinery and Equipment
# 141   Machinery and Equipment
# 154   Machinery and Equipment
# 157   Machinery and Equipment
# 159   Machinery and Equipment
# 161   Machinery and Equipment
# 163   Machinery and Equipment
# 165   Machinery and Equipment
# 168   Machinery and Equipment
# 169   Machinery and Equipment
# 173   Machinery and Equipment
# 176   Machinery and Equipment
# 179   Machinery and Equipment
# 180   Machinery and Equipment
# 181   Machinery and Equipment
# 184   Machinery and Equipment
# 185   Machinery and Equipment
# 186   Machinery and Equipment
# 189   Machinery and Equipment
# 190   Machinery and Equipment
# ...

# %%
nusrat= df['Upstream measurees']=='Machinery and Equipment'
df[nusrat]
# Out:
#            Upstream measurees  \
# 0     Machinery and Equipment
# 1     Machinery and Equipment
# 7     Machinery and Equipment
# 18    Machinery and Equipment
# 20    Machinery and Equipment
# 21    Machinery and Equipment
# 109   Machinery and Equipment
# 111   Machinery and Equipment
# 121   Machinery and Equipment
# 135   Machinery and Equipment
# 136   Machinery and Equipment
# 141   Machinery and Equipment
# 154   Machinery and Equipment
# 157   Machinery and Equipment
# 159   Machinery and Equipment
# 161   Machinery and Equipment
# 163   Machinery and Equipment
# 165   Machinery and Equipment
# 168   Machinery and Equipment
# 169   Machinery and Equipment
# 173   Machinery and Equipment
# 176   Machinery and Equipment
# 179   Machinery and Equipment
# 180   Machinery and Equipment
# 181   Machinery and Equipment
# 184   Machinery and Equipment
# 185   Machinery and Equipment
# 186   Machinery and Equipment
# 189   Machinery and Equipment
# 190   Machinery and Equipment
# ...

# %%
len(df[nusrat])
# Out:
# 291

# %%
df['Upstream measurees'].describe()
# Out:
# count                        1200
# unique                         55
# top       Machinery and Equipment
# freq                          291
# Name: Upstream measurees, dtype: object

# %%
df['INJURY SEVERITY'].describe()
# Out:
# count             1200
# unique               5
# top       Hospitalized
# freq               565
# Name: INJURY SEVERITY, dtype: object
